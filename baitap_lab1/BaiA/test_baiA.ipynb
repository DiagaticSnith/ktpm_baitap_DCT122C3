# %%
# %%writefile test1.inp
# 16
# Out:
# Overwriting test1.inp

# %%
# %%writefile test2.inp
# 9
# Out:
# Overwriting test2.inp

# %%
# !g++ bai_A.cpp -o bai_A
# !./bai_A <test1.inp >out1.txt
# !./bai_A <test2.inp >out2.txt

# %%
# !for f in out1.txt out2.txt; do cat $f; echo; done
# Out:
# 32
# -9
