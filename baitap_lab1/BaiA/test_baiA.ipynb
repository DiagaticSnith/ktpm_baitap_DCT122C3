# %%
# %%writefile test1.inp
# 9
# Out:
# Writing test1.inp

# %%
# %%writefile test2.inp
# 16
# Out:
# Writing test2.inp

# %%
# %%writefile test3.inp
# 10
# Out:
# Writing test3.inp

# %%
# !g++ bai_A.cpp -o bai_A
# !./bai_A <test1.inp >out1.txt
# !./bai_A <test2.inp >out2.txt
# !./bai_A <test3.inp >out3.txt

# %%
# !for f in out1.txt out2.txt out3.txt; do cat $f; echo; done
# Out:
# -9
# 32
# -10
