# %%
# %%writefile test1.inp
# 9
# Out:
# Writing test1.inp

# %%
# %%writefile test2.inp
# 13
# Out:
# Writing test2.inp

# %%
# %%writefile test3.inp
# -5
# Out:
# Writing test3.inp

# %%
# !g++ bai_B.cpp -o bai_B
# !./bai_B <test1.inp >out1.txt
# !./bai_B <test2.inp >out2.txt
# !./bai_B <test3.inp >out3.txt

# %%
# !for f in out1.txt out2.txt out3.txt; do cat $f; echo; done
# Out:
# -9
# 26
# -10
