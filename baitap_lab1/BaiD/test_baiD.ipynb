# %%
# %%writefile test1.inp
# 2
# Out:
# Overwriting test1.inp

# %%
# %%writefile test2.inp
# 10
# Out:
# Overwriting test2.inp

# %%
# %%writefile test3.inp
# 1
# Out:
# Overwriting test3.inp

# %%
# !g++ bai_D.cpp -o bai_D
# !./bai_D <test1.inp >out1.txt
# !./bai_D <test2.inp >out2.txt
# !./bai_D <test3.inp >out3.txt

# %%
# !for f in out1.txt out2.txt out3.txt; do cat $f; echo; done
# Out:
# 4
# 20
# 2
