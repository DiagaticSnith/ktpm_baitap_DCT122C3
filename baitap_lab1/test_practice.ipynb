# %%
# %%writefile test1.inp
# 0 0 0
# Out:
# Writing test1.inp

# %%
# %%writefile test2.inp
# 0 0 1
# Out:
# Writing test2.inp

# %%
# %%writefile test3.inp
# 0 1 -4
# Out:
# Writing test3.inp

# %%
# %%writefile test4.inp
# 1 0 -4
# Out:
# Writing test4.inp

# %%
# %%writefile test5.inp
# 1 0 4
# Out:
# Writing test5.inp

# %%
# %%writefile test6.inp
# 1 -6 8
# Out:
# Writing test6.inp

# %%
# !g++ Practice.cpp -o Practice
# !./Practice <test1.inp >out1.txt
# !./Practice <test2.inp >out2.txt
# !./Practice <test3.inp >out3.txt
# !./Practice <test4.inp >out4.txt
# !./Practice <test5.inp >out5.txt
# !./Practice <test6.inp >out6.txt

# %%
# !for f in out1.txt out2.txt out3.txt out4.txt out5.txt out6.txt; do cat $f; echo; done
# Out:
#  Infinite solutions.
#
# No solution.
#
#  The equation has 2 real solution(s): 2 -2
#
#  The equation has 2 real solution(s): 1.41421 -1.41421
#
# No solution.
#
#  The equation has 4 real solution(s): 2 -2 1.41421 -1.41421
